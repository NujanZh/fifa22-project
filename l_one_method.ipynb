# %%
import pandas as pd # dataframes
import numpy as np # matrices and linear algebra
import matplotlib.pyplot as plt # plotting
import seaborn as sns # another matplotlib interface - styled and easier to use

# %%
df_full = pd.read_csv('data/players_fifa22.csv')
df_full.head()
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   34     170
# 1  188545     R. Lewandowski            Robert Lewandowski   32     185
# 2   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3  231747          K. Mbappé                 Kylian Mbappé   22     182
# 4  200389           J. Oblak                     Jan Oblak   28     188
#
#    Weight                                          PhotoUrl Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# 1      81  https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 2      83  https://cdn.sofifa.com/players/020/801/22_60.png    Portugal
# 3      73  https://cdn.sofifa.com/players/231/747/22_60.png      France
# 4      87  https://cdn.sofifa.com/players/200/389/22_60.png    Slovenia
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# ...

# %%
df_full.tail()
# Out:
#            ID           Name       FullName  Age  Height  Weight  \
# 19255  262759       S. Black  Stephen Black   19     180      75
# 19256  250978        Ma Zhen        Zhen Ma   23     196      85
# 19257  261985     Yang Haoyu     Haoyu Yang   20     183      77
# 19258  261977       He Siwei       Siwei He   20     174      69
# 19259  261932  Chen Guoliang  Guoliang Chen   22     186      70
#
#                                                PhotoUrl          Nationality  \
# 19255  https://cdn.sofifa.com/players/262/759/22_60.png  Republic of Ireland
# 19256  https://cdn.sofifa.com/players/250/978/22_60.png             China PR
# 19257  https://cdn.sofifa.com/players/261/985/22_60.png             China PR
# 19258  https://cdn.sofifa.com/players/261/977/22_60.png             China PR
# 19259  https://cdn.sofifa.com/players/261/932/22_60.png             China PR
#
#        Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating  \
# ...

# %%
df_full.tail(20)
# Out:
#            ID               Name               FullName  Age  Height  Weight  \
# 19240  259175          N. Prabhu          Nikhil Prabhu   20     176      68
# 19241  264016          C. Mutawe         Charles Mutawe   20     184      60
# 19242  262034           R. Mahon           Robbie Mahon   18     168      58
# 19243  261548           A. Nawab             Aqib Nawab   19     175      56
# 19244  252332          Zhang Wei              Wei Zhang   21     186      74
# 19245  263340  H. Wiles-Richards  Harvey Wiles-Richards   19     180      72
# 19246  258987      Ruan Zhexiang          Zhexiang Ruan   24     178      70
# 19247  259745           H. Singh      Harmanpreet Singh   19     176      71
# 19248  243101          Zhang Hui              Hui Zhang   24     185      72
# 19249  257691           Liao Wei               Wei Liao   22     176      68
# 19250  257934          Guo Yunqi              Yunqi Guo   24     175      66
# ...

# %%
df_full.isna()
# Out:
#           ID   Name  FullName    Age  Height  Weight  PhotoUrl  Nationality  \
# 0      False  False     False  False   False   False     False        False
# 1      False  False     False  False   False   False     False        False
# 2      False  False     False  False   False   False     False        False
# 3      False  False     False  False   False   False     False        False
# 4      False  False     False  False   False   False     False        False
# ...      ...    ...       ...    ...     ...     ...       ...          ...
# 19255  False  False     False  False   False   False     False        False
# 19256  False  False     False  False   False   False     False        False
# 19257  False  False     False  False   False   False     False        False
# 19258  False  False     False  False   False   False     False        False
# 19259  False  False     False  False   False   False     False        False
#
# ...

# %% [markdown]
# # Null Columns
# You can see there are several null columns:

# %%
null_cols = df_full.columns[df_full.isna().any()].tolist()
null_cols
# Out:
# ['ClubPosition',
#  'ContractUntil',
#  'ClubNumber',
#  'NationalPosition',
#  'NationalNumber']

# %%
null_summary = df_full.isna().sum()
null_cols_with_count = null_summary[null_summary > 0]
null_cols_with_count
# Out:
# ClubPosition           76
# ContractUntil          76
# ClubNumber             76
# NationalPosition    18503
# NationalNumber      18503
# dtype: int64

# %%
df_full.describe()
# Out:
#                   ID           Age        Height        Weight       Overall  \
# count   19260.000000  19260.000000  19260.000000  19260.000000  19260.000000
# mean   231682.741952     25.184683    181.305036     74.950779     65.815628
# std     26960.272515      4.737340      6.866151      7.066864      6.817297
# min        41.000000     16.000000    155.000000     49.000000     48.000000
# 25%    214903.500000     21.000000    176.000000     70.000000     62.000000
# 50%    236687.500000     25.000000    181.000000     75.000000     66.000000
# 75%    253607.500000     29.000000    186.000000     80.000000     70.000000
# max    264705.000000     54.000000    206.000000    110.000000     93.000000
#
#           Potential        Growth    TotalStats     BaseStats      ValueEUR  \
# count  19260.000000  19260.000000  19260.000000  19260.000000  1.926000e+04
# mean      71.100104      5.284476   1598.525909    357.062461  2.857652e+06
# ...

# %%
df_full.shape
# Out:
# (19260, 90)

# %%
df_full.dtypes
# Out:
# ID            int64
# Name         object
# FullName     object
# Age           int64
# Height        int64
#               ...
# RWBRating     int64
# LBRating      int64
# CBRating      int64
# RBRating      int64
# GKRating      int64
# Length: 90, dtype: object

# %%
df_full.columns.tolist()
# Out:
# ['ID',
#  'Name',
#  'FullName',
#  'Age',
#  'Height',
#  'Weight',
#  'PhotoUrl',
#  'Nationality',
#  'Overall',
#  'Potential',
#  'Growth',
#  'TotalStats',
#  'BaseStats',
#  'Positions',
#  'BestPosition',
#  'Club',
#  'ValueEUR',
#  'WageEUR',
#  'ReleaseClause',
#  'ClubPosition',
#  'ContractUntil',
#  'ClubNumber',
#  'ClubJoined',
#  'OnLoad',
#  'NationalTeam',
#  'NationalPosition',
#  'NationalNumber',
#  'PreferredFoot',
#  'IntReputation',
#  'WeakFoot',
#  'SkillMoves',
#  'AttackingWorkRate',
#  'DefensiveWorkRate',
#  'PaceTotal',
#  'ShootingTotal',
#  'PassingTotal',
#  'DribblingTotal',
#  'DefendingTotal',
#  'PhysicalityTotal',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
# ...

# %%
age = df_full['Age']
age
# Out:
# 0        34
# 1        32
# 2        36
# 3        22
# 4        28
#          ..
# 19255    19
# 19256    23
# 19257    20
# 19258    20
# 19259    22
# Name: Age, Length: 19260, dtype: int64

# %%
age.values
# Out:
# array([34, 32, 36, ..., 20, 20, 22], shape=(19260,))

# %%
age.max()
# Out:
# np.int64(54)

# %%
age.min()
# Out:
# np.int64(16)

# %%
df_full.iloc[:, 2]
# Out:
# 0                        Lionel Messi
# 1                  Robert Lewandowski
# 2        C. Ronaldo dos Santos Aveiro
# 3                       Kylian Mbappé
# 4                           Jan Oblak
#                      ...
# 19255                   Stephen Black
# 19256                         Zhen Ma
# 19257                      Haoyu Yang
# 19258                        Siwei He
# 19259                   Guoliang Chen
# Name: FullName, Length: 19260, dtype: object

# %%
df = df_full.loc[:, ['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'ValueEUR', 'WageEUR', 'BestPosition']]
df
# Out:
#            ID               Name  Age          Nationality  Overall  \
# 0      158023           L. Messi   34            Argentina       93
# 1      188545     R. Lewandowski   32               Poland       92
# 2       20801  Cristiano Ronaldo   36             Portugal       91
# 3      231747          K. Mbappé   22               France       91
# 4      200389           J. Oblak   28             Slovenia       91
# ...       ...                ...  ...                  ...      ...
# 19255  262759           S. Black   19  Republic of Ireland       48
# 19256  250978            Ma Zhen   23             China PR       48
# 19257  261985         Yang Haoyu   20             China PR       48
# 19258  261977           He Siwei   20             China PR       48
# 19259  261932      Chen Guoliang   22             China PR       48
#
#        Potential                               Club   ValueEUR  WageEUR  \
# 0             93                Paris Saint-Germain   78000000   320000
# ...

# %%
sns.scatterplot(data=df, x='ValueEUR', y='WageEUR')
# Out:
# <Axes: xlabel='ValueEUR', ylabel='WageEUR'>

# %%
sns.scatterplot(data=df, x='Overall', y='WageEUR')
# Out:
# <Axes: xlabel='Overall', ylabel='WageEUR'>

# %%
sns.scatterplot(data=df, x='Potential', y='WageEUR')
# Out:
# <Axes: xlabel='Potential', ylabel='WageEUR'>

# %%
# TODO: I need to improve this visualization
sns.boxplot(data=df, x='BestPosition', y='WageEUR')
# Out:
# <Axes: xlabel='BestPosition', ylabel='WageEUR'>

# %%
sns.regplot(data=df, x='Overall', y='WageEUR')
# Out:
# <Axes: xlabel='Overall', ylabel='WageEUR'>
